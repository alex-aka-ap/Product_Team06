# %%
import feedparser
from pprint import pprint
from bs4 import BeautifulSoup
import pandas as pd

url = "http://news.google.com/news?q=covid&hl=en-US&sort=date&gl=US&num=10&output=rss"

class ParseFeed():
    def __init__(self, url):
        self.feed_url = url
        
    def clean(self, html):
        '''
        Get the text from html and do some cleaning
        '''
        soup = BeautifulSoup(html)
        text = soup.get_text()
        text = text.replace('\xa0', ' ')
        return text

    def parse(self):
        newsDescription = []
        newsUrl = []
        newsDate = []
        
        '''
        Parse the URL, and print all the details of the news 
        '''        
        feeds = feedparser.parse(self.feed_url).entries
        
        for f in feeds:
            newsDescription.append(self.clean(f.get("description", "")))
            newsUrl.append(f.get("link", ""))
            newsDate.append(f.get("published", ""))
            
        df = pd.DataFrame({'Description':newsDescription, 'URL':newsUrl, 'Date Published':newsDate})            
        return df
    
htmlOutput = ""
feed = ParseFeed(url)
df = feed.parse()

# %%
df['Date'] = pd.to_datetime(df['Date Published'])
df = df.head(10).sort_values(by = ['Date'], ascending=False)

# Saving data to html output
htmlOutput = """<html><title>COVID-19 Daily News</title><body><style>
		body {
		  background-image: url('background.jpg');
		  background-repeat: no-repeat;
		  background-attachment: fixed;
		  background-size: cover;
		}
	  </style><center><h1>COVID-19 Daily News</h1></center><dl>"""

for index,row in df.iterrows():
    htmlOutput = htmlOutput + "<dt>" + row['Description'] + "</dt><dd>" + row['Date Published'] + "</dd><dd><a href =" + row['URL'] + ">" + row['URL'] + "</a></dd><br>"
htmlOutput = htmlOutput + "</dl></body></html>"
text_file = open("home.html", "w")
text_file.write(htmlOutput)
text_file.close()

df.to_csv('data.csv', index=False)
df
# Out:
#                                          Description  \
# 9  Ceremony at Seattle’s Green Lake Park honors t...
# 2  Colorado governor and spouse test positive for...
# 1  'It's bad. It's really bad': Anchorage nurses ...
# 5  US is 'rounding the corner into a calamity,' e...
# 3  Baltimore Ravens add six more to reserve/COVID...
# 8  Wisconsin reports 28 more deaths from COVID-19...
# 4  Tracking COVID-19 in Alaska: 2 deaths and 656 ...
# 7  Statement from Governor Carney on DEMA Directo...
# 6  MDH reports 45 new COVID-19 deaths, 9,040 new ...
# 0  COVID-19 Daily Update 11-28-2020  West Virgini...
#
#                                                  URL  \
# 9  https://www.king5.com/article/news/health/coro...
# 2  https://www.cnn.com/2020/11/28/politics/colora...
# 1  https://www.adn.com/alaska-news/anchorage/2020...
# 5  https://www.cnn.com/2020/11/28/health/us-coron...
# 3  https://www.espn.com/nfl/story/_/id/30408556/b...
# 8  https://kstp.com/minnesota-news/wisconsin-repo...
# 4  https://www.adn.com/alaska-news/2020/11/28/tra...
# 7  https://news.delaware.gov/2020/11/28/statement...
# 6  https://kstp.com/coronavirus/mdh-reports-45-ne...
# 0  https://dhhr.wv.gov/News/2020/Pages/COVID-19-D...
#
#                   Date Published                      Date
# 9  Sun, 29 Nov 2020 03:59:00 GMT 2020-11-29 03:59:00+00:00
# 2  Sun, 29 Nov 2020 03:33:00 GMT 2020-11-29 03:33:00+00:00
# 1  Sun, 29 Nov 2020 00:42:06 GMT 2020-11-29 00:42:06+00:00
# 5  Sun, 29 Nov 2020 00:17:00 GMT 2020-11-29 00:17:00+00:00
# 3  Sat, 28 Nov 2020 22:59:09 GMT 2020-11-28 22:59:09+00:00
# 8  Sat, 28 Nov 2020 21:44:16 GMT 2020-11-28 21:44:16+00:00
# 4  Sat, 28 Nov 2020 20:23:37 GMT 2020-11-28 20:23:37+00:00
# 7  Sat, 28 Nov 2020 20:09:07 GMT 2020-11-28 20:09:07+00:00
# 6  Sat, 28 Nov 2020 17:13:48 GMT 2020-11-28 17:13:48+00:00
# 0  Sat, 28 Nov 2020 15:01:25 GMT 2020-11-28 15:01:25+00:00
